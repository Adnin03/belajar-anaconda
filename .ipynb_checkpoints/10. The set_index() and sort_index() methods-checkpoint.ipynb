# %%
import pandas as pd

# %%
# reading and showing dataframe
df_exam = pd.read_csv('StudentsPerformance.csv')
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
# [1000 rows x 8 columns]

# %% [markdown]
# ## 1. Create Index

# %%
import numpy as np
import random

# %%
# creating non repetitive values for the index
new_index = np.arange(0, 1000)

# %%
# shuffling the indexes
random.shuffle(new_index)

# %%
# create a new column with new index
df_exam['new_index'] = new_index
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          72             72             74
# 1                 completed          69             90             88
# 2                      none          90             95             93
# 3                      none          47             57             44
# 4                      none          76             78             75
# ..                      ...         ...            ...            ...
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86
#
#      new_index
# 0          108
# 1          188
# 2          657
# 3          194
# 4          331
# ..         ...
# 995         66
# 996        394
# 997        169
# 998        791
# 999        766
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## 2. Set Index

# %%
# set new_index column as index
df_exam.set_index(new_index, inplace=True)
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 108  female        group B           bachelor's degree      standard
# 188  female        group C                some college      standard
# 657  female        group B             master's degree      standard
# 194    male        group A          associate's degree  free/reduced
# 331    male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 66   female        group E             master's degree      standard
# 394    male        group C                 high school  free/reduced
# 169  female        group C                 high school  free/reduced
# 791  female        group D                some college      standard
# 766  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 108                    none          72             72             74
# 188               completed          69             90             88
# 657                    none          90             95             93
# 194                    none          47             57             44
# 331                    none          76             78             75
# ..                      ...         ...            ...            ...
# 66                completed          88             99             95
# 394                    none          62             55             55
# 169               completed          59             71             65
# 791               completed          68             78             77
# 766                    none          77             86             86
#
#      new_index
# 108        108
# 188        188
# 657        657
# 194        194
# 331        331
# ..         ...
# 66          66
# 394        394
# 169        169
# 791        791
# 766        766
#
# [1000 rows x 9 columns]

# %% [markdown]
# ## Sort Index

# %%
# sort dataframe by new index
df_exam.sort_index()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group C                some college      standard
# 1    female        group D          associate's degree      standard
# 2    female        group E                some college      standard
# 3    female        group D                 high school      standard
# 4      male        group D            some high school      standard
# ..      ...            ...                         ...           ...
# 995    male        group E            some high school      standard
# 996  female        group E          associate's degree      standard
# 997  female        group D                 high school  free/reduced
# 998    male        group D                some college      standard
# 999  female        group C            some high school  free/reduced
#
#     test preparation course  math score  reading score  writing score  \
# 0                      none          53             62             56
# 1                      none          71             71             74
# 2                 completed          86             85             91
# 3                      none          45             63             59
# 4                 completed          89             88             82
# ..                      ...         ...            ...            ...
# 995               completed          77             76             77
# 996               completed          93            100             95
# 997                    none          39             52             46
# 998                    none          71             49             52
# 999               completed          50             60             60
#
#      new_index
# 0            0
# 1            1
# 2            2
# 3            3
# 4            4
# ..         ...
# 995        995
# 996        996
# 997        997
# 998        998
# 999        999
#
# [1000 rows x 9 columns]

# %%
# sort descending by index
df_exam.sort_index(ascending=False, inplace=True)

# %%
df_exam
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 999  female        group C            some high school  free/reduced
# 998    male        group D                some college      standard
# 997  female        group D                 high school  free/reduced
# 996  female        group E          associate's degree      standard
# 995    male        group E            some high school      standard
# ..      ...            ...                         ...           ...
# 4      male        group D            some high school      standard
# 3    female        group D                 high school      standard
# 2    female        group E                some college      standard
# 1    female        group D          associate's degree      standard
# 0    female        group C                some college      standard
#
#     test preparation course  math score  reading score  writing score  \
# 999               completed          50             60             60
# 998                    none          71             49             52
# 997                    none          39             52             46
# 996               completed          93            100             95
# 995               completed          77             76             77
# ..                      ...         ...            ...            ...
# 4                 completed          89             88             82
# 3                      none          45             63             59
# 2                 completed          86             85             91
# 1                      none          71             71             74
# 0                      none          53             62             56
#
#      new_index
# 999        999
# 998        998
# 997        997
# 996        996
# 995        995
# ..         ...
# 4            4
# 3            3
# 2            2
# 1            1
# 0            0
#
# [1000 rows x 9 columns]
