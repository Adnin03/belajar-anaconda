# %%
import pandas as pd

# %%
# read the csv file
df = pd.read_csv('players_20.csv')
# set index
df.set_index('short_name', inplace=True)
# select column
df = df[['long_name', 'age',	'dob', 'height_cm',	'weight_kg', 'nationality',	'club']]

# %%
# show dataframe
df
# Out:
#                                              long_name  age         dob  \
# short_name
# L. Messi                Lionel Andrés Messi Cuccittini   32  1987-06-24
# Cristiano Ronaldo  Cristiano Ronaldo dos Santos Aveiro   34  1985-02-05
# Neymar Jr                Neymar da Silva Santos Junior   27  1992-02-05
# J. Oblak                                     Jan Oblak   26  1993-01-07
# E. Hazard                                  Eden Hazard   28  1991-01-07
# ...                                                ...  ...         ...
# Shao Shuai                                          邵帅   22  1997-03-10
# Xiao Mingjie                              Mingjie Xiao   22  1997-01-01
# Zhang Wei                                           张威   19  2000-05-16
# Wang Haijian                                       汪海健   18  2000-08-02
# Pan Ximing                                         潘喜明   26  1993-01-11
#
#                    height_cm  weight_kg nationality  \
# short_name
# ...

# %% [markdown]
# ## 1. sample()

# %%
# extract 10 random elements from the 'nationality' column
df['nationality'].sample(10, random_state=99)
# Out:
# short_name
# R. Alvarado               Mexico
# Qiao Wei                China PR
# E. Paredes                 Chile
# K. Stoyanov             Bulgaria
# M. Chudý                Slovakia
# D. Sundaram                India
# R. Gagliardini             Italy
# G. Debeljuh              Croatia
# Kim Seung Yong    Korea Republic
# M. Hansen                Denmark
# Name: nationality, dtype: object

# %%
# extract a random 20% sample of the dataframe
df.sample(frac=0.2, random_state=10)
# Out:
#                                           long_name  age         dob  \
# short_name
# F. Ortega                          Francisco Ortega   20  1999-03-19
# M. Ilaimaharitra                Marco Ilaimaharitra   23  1995-07-26
# D. Parker                            Devante Parker   23  1996-03-16
# H. Mendoza        Humberto Antonio Mendoza Quiñónez   34  1984-10-02
# K. Qaka                                  Kamer Qaka   24  1995-04-11
# ...                                             ...  ...         ...
# A. Koșelev                           Alexei Koșelev   25  1993-11-19
# P. Ejimadu                          Phillip Ejimadu   19  1999-08-31
# E. List                                Elliott List   22  1997-05-12
# V. Bondarenko                    Valeriy Bondarenko   25  1994-02-03
# T. Chunchukov                  Tsvetelin Chunchukov   24  1994-12-26
#
#                   height_cm  weight_kg    nationality                   club
# short_name
# ...

# %%
# upsample: increase the sampling rate -> frac>1 (Note: replace parameter has to be True for frac parameter > 1)
df.sample(frac=2, replace=True, random_state=29)
# Out:
#                                         long_name  age         dob  height_cm  \
# short_name
# I. Obradović                       Ivan Obradović   30  1988-07-25        181
# D. Bouzanis                         Dean Bouzanis   28  1990-10-02        185
# A. Selikhov                     Alexandr Selikhov   25  1994-04-07        188
# Raffael                 Raffael Caetano de Araújo   34  1985-03-28        174
# N. Çiftçi                            Nadir Çiftçi   27  1992-02-12        185
# ...                                           ...  ...         ...        ...
# B. Touré                      Ibrahim Blati Touré   24  1994-08-04        170
# V. Lia                                  Vince Lia   34  1985-03-18        177
# G. Rólantsson Sørensen  Gilli Rólantsson Sørensen   26  1992-08-11        187
# E. García                         Emmanuel García   29  1989-12-28        168
# K. Nordfeldt                 Kristoffer Nordfeldt   30  1989-06-23        190
#
# ...
